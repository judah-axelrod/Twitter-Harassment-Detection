# %%
import numpy as np
import pandas as pd
import re
from fuzzywuzzy import fuzz
import string
import matplotlib.pyplot as plt
from pandarallel import pandarallel
pd.set_option('display.max_rows', 500)

# %% [markdown]
# ## Import Data

# %%
r_golbeck = pd.read_csv('Golbeck/onlineHarassmentDataset.tsv', delimiter='\t', encoding='latin-1')
r_golbeck.head()
# Out:
#    ID Code                                              Tweet
# 0   1    H  @Grumpy_P_Sloth @deanesmay feminists argue for...
# 1   2    H  1948Army of England helped the Jews to occupy ...
# 2   3    H  Dutch Leader Says Europe to collapse In 6 Week...
# 3   4    H  RT @__DeLay: The next day the Romans and the J...
# 4   5    H  RT @Bakersman_Joe: When Hitler Invited The Jew...

# %% [markdown]
# ## Cleaning
# #### Apply same cleaning steps as in data build notebook

# %%
from preprocessTwitter import tokenize #Python version of Ruby preprocessing script

def clean_tweets(tweet):
    tweet = re.sub('^RT:? ','<rt> ',tweet) #Assign special char to RTs
    tweet = re.sub('RT@','<rt> @',tweet) #Split out RT and user mention when overlapping
    tweet = re.sub('via@','via @',tweet) #Split out 'via' and user mention when overlapping
    tweet = re.sub(r'https?: ?/ ?/t(.co( )?)?/?[A-Za-z0-9é]*|https?:\\/\\/t.co\\/[A-Za-z0-9]*é?|https?(: / /)?é?', '<url>', tweet) #Assign special char to URLs (Python script missing some cases that I do not)
    tweet = re.sub(r'<url>é|<url> ?\.c[oé]*$', '<url>', tweet, flags=re.IGNORECASE) 
    tweet = re.sub(r"'", '', re.sub(r'"', '', tweet)) #Get rid of single and double quotes (admittedly loses some context here)
    tweet = re.sub('anti-', 'anti ', tweet, flags=re.IGNORECASE) #Capture 'anti' or 'non' prefix as its own word 
    tweet = re.sub('#anti', '#anti ', tweet, flags=re.IGNORECASE)
    tweet = re.sub(' anti', ' anti ', tweet, flags=re.IGNORECASE)
    tweet = re.sub('non-', 'non ', tweet, flags=re.IGNORECASE)
    tweet = re.sub('&amp;?', '&', tweet, flags=re.IGNORECASE) #Put ampersand in recognizable format
    #Clean some known hateful terms that are in the data (e.g. "whitepower") to extract meaning from hashtags
    tweet = re.sub('#white', '#white ', tweet, flags=re.IGNORECASE)
    tweet = re.sub('waronwhite', 'war on white', tweet, flags=re.IGNORECASE)
    tweet = re.sub('whitegenocide', 'white genocide', tweet, flags = re.IGNORECASE)
    tweet = re.sub('whitelivesmatter', 'white lives matter', tweet, flags = re.IGNORECASE)
    tweet = re.sub('blacklivesmatter', 'black lives matter', tweet, flags = re.IGNORECASE)
    tweet = re.sub('livesmatter', 'lives matter', tweet, flags = re.IGNORECASE)
    tweet = re.sub('alllive', 'all live', tweet, flags = re.IGNORECASE)
    tweet = re.sub('bluelive', 'blue live', tweet, flags = re.IGNORECASE)
    tweet = re.sub('whitepower', 'white power', tweet, flags = re.IGNORECASE)
    tweet = re.sub('#fuck', '#fuck ', tweet, flags=re.IGNORECASE)
    tweet = re.sub('fuckniggers', 'fuck niggers', tweet, flags=re.IGNORECASE)
    tweet = re.sub('sjw', 'social justice warrior', tweet, flags=re.IGNORECASE)
    tweet = tweet.strip() #Strip whitespace
    return tweet

# %%
r_golbeck['tokens'] = r_golbeck['Tweet'].apply(clean_tweets) #Apply my own cleaning steps
r_golbeck['tokens'] = r_golbeck['tokens'].apply(tokenize) #Then apply the ones implemented here: https://nlp.stanford.edu/projects/glove/preprocess-twitter.rb
r_golbeck['tokens'] = r_golbeck['tokens'].apply(lambda x:re.sub('><', '> <', x)) #Separate any special characters that are overlapping/touching
r_golbeck.head()
# Out:
#    ID Code                                              Tweet  \
# 0   1    H  @Grumpy_P_Sloth @deanesmay feminists argue for...
# 1   2    H  1948Army of England helped the Jews to occupy ...
# 2   3    H  Dutch Leader Says Europe to collapse In 6 Week...
# 3   4    H  RT @__DeLay: The next day the Romans and the J...
# 4   5    H  RT @Bakersman_Joe: When Hitler Invited The Jew...
#
#                                               tokens
# 0  <user> <user> feminists argue for raising mini...
# 1  <number>army of england helped the jews to occ...
# 2  dutch leader says europe to collapse in <numbe...
# 3  <rt> <user> : the next day the romans and the ...
# 4  <rt> <user> : when hitler invited the jews to ...

# %% [markdown]
# ## Fuzzy Matching
# #### Apply fuzzy matching to tweets to search for duplicate tweets with differing labels

# %%
fuzz_similarity = r_golbeck[['ID','Code','tokens']]
fuzz_similarity = fuzz_similarity.merge(fuzz_similarity, how='cross') #Cartesian join all tweets
print(fuzz_similarity.shape)
fuzz_similarity.head()
# Out:
# (414529600, 6)
#    ID_x Code_x                                           tokens_x  ID_y  \
# 0     1      H  <user> <user> feminists argue for raising mini...     1
# 1     1      H  <user> <user> feminists argue for raising mini...     2
# 2     1      H  <user> <user> feminists argue for raising mini...     3
# 3     1      H  <user> <user> feminists argue for raising mini...     4
# 4     1      H  <user> <user> feminists argue for raising mini...     5
#
#   Code_y                                           tokens_y
# 0      H  <user> <user> feminists argue for raising mini...
# 1      H  <number>army of england helped the jews to occ...
# 2      H  dutch leader says europe to collapse in <numbe...
# 3      H  <rt> <user> : the next day the romans and the ...
# 4      H  <rt> <user> : when hitler invited the jews to ...

# %%
#Limit to rows where the tweet ID isn't identical (exact same tweet) and the labels are different
fuzz_similarity = fuzz_similarity[(fuzz_similarity['Code_x'] != fuzz_similarity['Code_y']) &
                                  ((fuzz_similarity['ID_x'] != fuzz_similarity['ID_y']))]
print(fuzz_similarity.shape)
fuzz_similarity.head()
# Out:
# (159341338, 6)
#     ID_x Code_x                                           tokens_x  ID_y  \
# 37     1      H  <user> <user> feminists argue for raising mini...    38
# 38     1      H  <user> <user> feminists argue for raising mini...    39
# 39     1      H  <user> <user> feminists argue for raising mini...    40
# 40     1      H  <user> <user> feminists argue for raising mini...    41
# 41     1      H  <user> <user> feminists argue for raising mini...    42
#
#    Code_y                                           tokens_y
# 37      N  for the record , i see tax havens as the next ...
# 38      N  this is our <hashtag> israel , this is for the...
# 39      N  <user> <user> <user>  >reading the nt  <allcap...
# 40      N  <user> go for if its a quasi free socitey for ...
# 41      N  <user> throw a chaw in before you go mudding <...

# %% [markdown]
# #### Compute fuzzy ratio for each pair of tweets in parallel (value of 100 = exact same string)
# Note: This process will take several hours even with 8 worker nodes running in parallel

# %%
# import time (if you want to track how long this takes)

pandarallel.initialize(progress_bar=True)
# t0 = time.time()
ratios = fuzz_similarity.parallel_apply(lambda x: fuzz.ratio(x.tokens_x, x.tokens_y), axis=1)
# t1 = time.time()

# print(t1-t0)
# Out:
# INFO: Pandarallel will run on 8 workers.
# INFO: Pandarallel will use standard multiprocessing data transfer (pipe) to transfer data between the main process and workers.
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=19917668), Label(value='0 / 199176…

# %% [markdown]
# #### After some exploration, settled on a fuzzy score of 85 of the minimum threshold for two tweets being considered "duplicates".
# Here are the examples with that minimum score:

# %%
fuzz_similarity[fuzz_similarity['score']==85]
# Out:
#             ID_x Code_x                                           tokens_x  \
# 4140712      204      H                    <user> untag you fucking nigger
# 4948749      244      H        <user> : <hashtag> white lives matter <url>
# 4955619      244      H        <user> : <hashtag> white lives matter <url>
# 4956089      244      H        <user> : <hashtag> white lives matter <url>
# 4956287      244      H        <user> : <hashtag> white lives matter <url>
# 4956299      244      H        <user> : <hashtag> white lives matter <url>
# 6023014      296      H                        <user> : gas the jews <url>
# 8883453      437      H                      <user> yes you fucking nigger
# 9914511      487      N                <user> <hashtag> white lives matter
# 10094810     496      H  <user> : i set fire to the jews was also a goo...
# 11499136     565      H  <user> : i bet the jews did nazi us coming ! -...
# 14434181     709      N                    <hashtag> white lives mattertoo
# 17595333     865      N    hamas to kids : shoot all the jews <user> <url>
# 23855851    1172      H  <rt> <user> : <user> <user> diversity = <hasht...
# 24250417    1192      H  <rt> <user> : cucks <hashtag> white genocide <...
# 24255499    1192      H  <rt> <user> : cucks <hashtag> white genocide <...
# 24255885    1192      H  <rt> <user> : cucks <hashtag> white genocide <...
# 24262754    1192      H  <rt> <user> : cucks <hashtag> white genocide <...
# 24263518    1192      H  <rt> <user> : cucks <hashtag> white genocide <...
# 24347042    1196      H  <rt> <user> : say no to <hashtag> white genoci...
# 25837083    1270      N     <rt> <user> : <hashtag> white lives mattermore
# 26630350    1308      N  <rt> <user> : diversity is a racist euphemism ...
# 26971448    1325      H       <rt> <user> : <hashtag> white powerwednesday
# 29292522    1439      H  <rt> <user> : yes . <hashtag> war on whites <h...
# 29295109    1439      H  <rt> <user> : yes . <hashtag> war on whites <h...
# 29464184    1448      N  <rt> <user> : <user> flooding all  <allcaps> &...
# 30891510    1518      N  <rt> <user> : love your race . <hashtag> white...
# 30905942    1518      N  <rt> <user> : love your race . <hashtag> white...
# 30906235    1518      N  <rt> <user> : love your race . <hashtag> white...
# 30906236    1518      N  <rt> <user> : love your race . <hashtag> white...
# 30906237    1518      N  <rt> <user> : love your race . <hashtag> white...
# 30906238    1518      N  <rt> <user> : love your race . <hashtag> white...
# 35591909    1749      N  <rt> <user> : i said a glass of juice , not ga...
# 35608543    1749      N  <rt> <user> : i said a glass of juice , not ga...
# 36223787    1780      N  <rt> <user> : diversity is code for <hashtag> ...
# 39115452    1922      N  <rt> <user> : <hashtag> brexit <hashtag> u kin...
# 42578748    2092      N                <rt> <user> : <hashtag> white power
# 42592131    2092      N                <rt> <user> : <hashtag> white power
# 44098320    2166      H  <rt> <user> : white nationalism : the controve...
# 45062258    2214      N  <rt> <user> genocidehc : <user> <user> <user> ...
# 53528188    2630      H  i said a glass of juice , not gas the jews -hi...
# 64720350    3179      H                     <user> : <hashtag> white power
# 66456487    3265      H  <user> flooding all  <allcaps> & only  <allcap...
# 68146699    3348      H  <user> <hashtag> diversity is a codeword for <...
# 70819857    3479      H                     <user> <user> blame the jews !
# 70820351    3479      H                     <user> <user> blame the jews !
# 71775516    3526      H                               <user> kill the jews
# 77924737    3828      H            <user> you are a massive fucking faggot
# 79149760    3888      H  <hashtag> belgium the shias are the donkeys of...
# 79243041    3893      H  <hashtag> caucus for trump asia for the asians...
# 79243056    3893      H  <hashtag> caucus for trump asia for the asians...
# 81022830    3980      H  <hashtag> virginia the shias are the donkeys o...
# 81103330    3984      H                       <hashtag> white lives matter
# 81105867    3984      H                       <hashtag> white lives matter
# 81112940    3984      H                       <hashtag> white lives matter
# 87406344    4294      H  hamas to kids : shoot all the jews <url> <user...
# 89820052    4412      H         i raped the jews because it touched dave .
# 97729873    4801      H  <rt> <user> : i would have killed all the jews...
# 99719834    4898      H  <rt> <user> : you  <allcaps> fucking nigger  <...
# 99861980    4905      H  <rt> <user> : i could have killed all the jews...
# 101775213   4999      H                 <rt> <user> : wake n bake the jews
# 102907334   5055      H                <rt> <user> : <hashtag> white power
# 104508040   5134      H  <rt> <user> : <user> <hashtag> white genocide ...
# 104870876   5151      H  <rt> <user> : when nazis did this , global out...
# 105053098   5160      H  <rt> <user> : white genocide in south africa :...
# 109741917   5391      H   <rt> <user> : <hashtag> white lives matter <url>
# 109749559   5391      H   <rt> <user> : <hashtag> white lives matter <url>
# 109756670   5391      H   <rt> <user> : <hashtag> white lives matter <url>
# 110162105   5411      H  <rt> <user> : professor khaleel mohammed says ...
# 113570293   5579      H  <rt> <user> : <user> <user> <user> diversity =...
# 121917771   5989      H               <user> : <hashtag> white power <url>
# 121922419   5989      H               <user> : <hashtag> white power <url>
# 121922805   5989      H               <user> : <hashtag> white power <url>
# 121923801   5989      H               <user> : <hashtag> white power <url>
# 121930037   5989      H               <user> : <hashtag> white power <url>
# 121931173   5989      H               <user> : <hashtag> white power <url>
# 121931400   5989      H               <user> : <hashtag> white power <url>
# 121932252   5989      H               <user> : <hashtag> white power <url>
# 126089302   6193      N  . <repeat>where is he who has been born king o...
# 132197916   6494      N                   <user> \nlmao you fucking nigger
# 132583389   6512      N        <user> : <url> <hashtag> white lives matter
# 132669285   6517      N                               <user> with the jews
# 137206609   6740      N              <user> <hashtag> white genocide <url>
# 137207231   6740      N              <user> <hashtag> white genocide <url>
# 138426831   6799      N                <user> <hashtag> white lives matter
# 139933471   6873      N                <user> <hashtag> white lives matter
# 142869947   7018      N                      <user> youre a fucking faggot
# 143394671   7043      N                <user> <hashtag> white lives matter
# 145065569   7126      N              <user> <hashtag> white genocide <url>
# 145066191   7126      N              <user> <hashtag> white genocide <url>
# 153004591   7515      N                <user> <hashtag> white lives matter
# 155387723   7633      N                <user> i want to you fucking nigger
# 156384351   7681      N                <user> <hashtag> white lives matter
# 158343198   7778      N                             <user> <user> the jews
# 160726894   7895      N                  <user> haha <hashtag> white power
# 165349548   8122      N                   <user> <hashtag> white power . .
# 165362931   8122      N                   <user> <hashtag> white power . .
# 165710283   8140      N         <user> <user> <hashtag> white lives matter
# 168401038   8272      N                           <user> <user> the jews ?
# 169760871   8338      N                <user> <hashtag> white lives matter
# 174097592   8551      N          <user> <hashtag> white lives matter <url>
# 174626911   8577      N                <user> <hashtag> white lives matter
# 175279483   8610      N         <user> <user> <hashtag> white lives matter
# 176459183   8667      N                               <user> <user> <user>
# 176459187   8667      N                               <user> <user> <user>
# 179310763   8808      N         <user> <user> <hashtag> white lives matter
# 179555083   8820      N         <user> <user> <hashtag> white lives matter
# 186252247   9148      N                                <user> for the jews
# 186482630   9160      N              <user> <hashtag> white lives matter !
# 186497062   9160      N              <user> <hashtag> white lives matter !
# 186497355   9160      N              <user> <hashtag> white lives matter !
# 186497356   9160      N              <user> <hashtag> white lives matter !
# 186497357   9160      N              <user> <hashtag> white lives matter !
# 186497358   9160      N              <user> <hashtag> white lives matter !
# 189896687   9327      N                                <user> for the jews
# 190243031   9344      N                <user> <hashtag> white lives matter
# 192405983   9451      N             <user> <hashtag> white lives mattertoo
# 192421429   9451      N             <user> <hashtag> white lives mattertoo
# 192421544   9451      N             <user> <hashtag> white lives mattertoo
# 192421545   9451      N             <user> <hashtag> white lives mattertoo
# 195536631   9604      N                <user> <hashtag> white lives matter
# 197409751   9696      N                <user> <hashtag> white lives matter
# 197959471   9723      N                <user> <hashtag> white lives matter
# 211544379  10391      N  <hashtag> new_ york the shias are the donkeys ...
# 212559028  10441      N  <hashtag> rhode_island the shias are the donke...
# 242385078  11905      N  heres where all the jews are hanging out on xm...
# 244059303  11988      N             how about <hashtag> white lives matter
# 244074864  11988      N             how about <hashtag> white lives matter
# 244074865  11988      N             how about <hashtag> white lives matter
# 246197531  12093      N        i ate the jews because it shouted at dave .
# 263885192  12961      N   lol - great ! <hashtag> white lives matter <url>
# 269606540  13242      N  never will the jews nor the christians be plea...
# 269606762  13242      N  never will the jews nor the christians be plea...
# 284919031  13995      N  <rt> <user> : <user> this is <hashtag> white g...
# 290965931  14292      N  <rt> <user> : <user> <user> diversity = <hasht...
# 292314508  14358      N                <rt> <user> : <hashtag> white power
# 292327891  14358      N                <rt> <user> : <hashtag> white power
# 295327210  14506      N  <rt> <user> : mt  <allcaps> <user> prof k moha...
# 299332123  14702      N  <rt> <user> : amen pat <hashtag> white lives m...
# 299332151  14702      N  <rt> <user> : amen pat <hashtag> white lives m...
# 299332301  14702      N  <rt> <user> : amen pat <hashtag> white lives m...
# 299332404  14702      N  <rt> <user> : amen pat <hashtag> white lives m...
# 300474071  14759      N  <rt> <user> : cultural marxism = <hashtag> whi...
# 301492204  14809      N  <rt> <user> : taggers ! <hashtag> white powerw...
# 302184558  14843      N  <rt> <user> : <hashtag> farm murders <hashtag>...
# 303424409  14903      N  <rt> <user> : isis  <allcaps> releases video i...
# 315443468  15494      N  <rt> <user> : <hashtag> white powerwednsday <url>
# 315456851  15494      N  <rt> <user> : <hashtag> white powerwednsday <url>
# 320065188  15721      N                <rt> <user> : <hashtag> white power
# 320078571  15721      N                <rt> <user> : <hashtag> white power
# 322874039  15859      N  <rt> <user> : this was south africa <url> <has...
# 324400878  15934      N                   <rt> <user> : where are the jews
# 327715124  16097      N  <rt> <user> : <user> : i bet the jews did nazi...
# 331260378  16271      N          <rt> <user> : <hashtag> white power <url>
# 331262590  16271      N          <rt> <user> : <hashtag> white power <url>
# 331276615  16271      N          <rt> <user> : <hashtag> white power <url>
# 331277022  16271      N          <rt> <user> : <hashtag> white power <url>
# 331277315  16271      N          <rt> <user> : <hashtag> white power <url>
# 331277316  16271      N          <rt> <user> : <hashtag> white power <url>
# 331277317  16271      N          <rt> <user> : <hashtag> white power <url>
# 331277318  16271      N          <rt> <user> : <hashtag> white power <url>
# 333984966  16404      N  <rt> <user> : happy birthday <user> <hashtag> ...
# 336759304  16541      N  <rt> <user> : i could have killed all the jews...
# 337411908  16573      N                <rt> <user> : <hashtag> white power
# 337425291  16573      N                <rt> <user> : <hashtag> white power
# 338180095  16611      N  <rt> <user> : i set fire to the jews was also ...
# 342333335  16815      N                   <rt> <user> : eat the jews <url>
# 342904315  16843      N  <rt> <user> : best <hashtag> white genocide gr...
# 344373937  16915      N  <rt> <user> : im  <allcaps> fucking done  <all...
# 348501493  17117      N  <rt> <user> : where is the one who has been bo...
# 354855878  17430      N  <rt> <user> : <hashtag> fight <hashtag> white ...
# 368576794  18103      N  the jews are in ethiopia rt  <allcaps> <user> ...
# 388065583  19061      N             wow <hashtag> white lives matter <url>
# 388081144  19061      N             wow <hashtag> white lives matter <url>
# 388081145  19061      N             wow <hashtag> white lives matter <url>
# 392196428  19264      H  i said a glass of juice , not gas the jews -hi...
# 392969068  19302      H                <user> <hashtag> white lives matter
# 393294188  19318      H  <user> sure since this is ok quran [<number>] ...
# 393506867  19328      H                              <user> so im the jews
# 393507046  19328      H                              <user> so im the jews
# 394395651  19372      H               <user> : <hashtag> white power <url>
# 394400299  19372      H               <user> : <hashtag> white power <url>
# 394400685  19372      H               <user> : <hashtag> white power <url>
# 394401681  19372      H               <user> : <hashtag> white power <url>
# 394407917  19372      H               <user> : <hashtag> white power <url>
# 394409053  19372      H               <user> : <hashtag> white power <url>
# 394409280  19372      H               <user> : <hashtag> white power <url>
# 394410132  19372      H               <user> : <hashtag> white power <url>
# 395305670  19416      H                     <user> : <hashtag> white power
# 395460946  19424      H                        <user> <user> <user> whut ?
# 395542386  19428      H                        <user> <user> <user> <user>
# 395580951  19430      H       <user> indeed . <hashtag> white lives matter
# 395583890  19430      H       <user> indeed . <hashtag> white lives matter
# 395642948  19433      H                       <user> <user> its the jews .
# 397925290  19545      H                       <hashtag> white lives matter
# 397927827  19545      H                       <hashtag> white lives matter
# 397934900  19545      H                       <hashtag> white lives matter
# 397945650  19546      H                       <hashtag> white lives matter
# 397948187  19546      H                       <hashtag> white lives matter
# 397955260  19546      H                       <hashtag> white lives matter
# 398058846  19552      H                    <hashtag> white lives mattertoo
# 398065158  19552      H                    <hashtag> white lives mattertoo
# 398065232  19552      H                    <hashtag> white lives mattertoo
# 398065402  19552      H                    <hashtag> white lives mattertoo
# 398065874  19552      H                    <hashtag> white lives mattertoo
# 398066040  19552      H                    <hashtag> white lives mattertoo
# 398066697  19552      H                    <hashtag> white lives mattertoo
# 398066936  19552      H                    <hashtag> white lives mattertoo
# 398067703  19552      H                    <hashtag> white lives mattertoo
# 398067963  19552      H                    <hashtag> white lives mattertoo
# 398068055  19552      H                    <hashtag> white lives mattertoo
# 398068082  19552      H                    <hashtag> white lives mattertoo
# 398901670  19593      H          blog : <hashtag> white lives matter <url>
# 399841584  19639      H        heres where the jews hang out on xmas <url>
# 400882942  19690      H  isis releases video in hebrew with a message t...
# 401780996  19734      H  mt <number> and asked , where is the one who h...
# 402389381  19764      H         <rt> <user> : <hashtag> white lives matter
# 402734041  19781      H  <rt> <user> : never will the jews nor the chri...
# 402959461  19792      H         <rt> <user> : <hashtag> white lives matter
# 403577437  19823      H   <rt> <user> : <hashtag> white lives matter <url>
# 403585079  19823      H   <rt> <user> : <hashtag> white lives matter <url>
# 403592190  19823      H   <rt> <user> : <hashtag> white lives matter <url>
# 403740107  19831      H  <rt> <user> : diversity / multiculturalism are...
# 404895363  19887      H         <rt> <user> : <user> <hashtag> white power
# 406013461  19942      H         <rt> <user> : <hashtag> white lives matter
# 407253961  20003      H  <rt> <user> : never will the jews nor the chri...
# 408110541  20045      H         <rt> <user> : <hashtag> white lives matter
# 408724742  20075      H  <rt> <user> : i traveled to paris today to sta...
# 409542917  20116      H   <rt> <user> : <hashtag> white lives matter <url>
# 409550559  20116      H   <rt> <user> : <hashtag> white lives matter <url>
# 409557670  20116      H   <rt> <user> : <hashtag> white lives matter <url>
# 409563277  20117      H   <rt> <user> : <hashtag> white lives matter <url>
# 409570919  20117      H   <rt> <user> : <hashtag> white lives matter <url>
# 409578030  20117      H   <rt> <user> : <hashtag> white lives matter <url>
# 409583637  20118      H   <rt> <user> : <hashtag> white lives matter <url>
# 409591279  20118      H   <rt> <user> : <hashtag> white lives matter <url>
# 409598390  20118      H   <rt> <user> : <hashtag> white lives matter <url>
# 409603997  20119      H   <rt> <user> : <hashtag> white lives matter <url>
# 409611639  20119      H   <rt> <user> : <hashtag> white lives matter <url>
# 409618750  20119      H   <rt> <user> : <hashtag> white lives matter <url>
# 410911712  20183      H  <rt> <user> : where is the one who has been bo...
#
#             ID_y Code_y                                           tokens_y  \
# 4140712     7633      N                <user> i want to you fucking nigger
# 4948749     1270      N     <rt> <user> : <hashtag> white lives mattermore
# 4955619     8140      N         <user> <user> <hashtag> white lives matter
# 4956089     8610      N         <user> <user> <hashtag> white lives matter
# 4956287     8808      N         <user> <user> <hashtag> white lives matter
# 4956299     8820      N         <user> <user> <hashtag> white lives matter
# 6023014    16815      N                   <rt> <user> : eat the jews <url>
# 8883453     6494      N                   <user> \nlmao you fucking nigger
# 9914511    19552      H                    <hashtag> white lives mattertoo
# 10094810   16611      N  <rt> <user> : i set fire to the jews was also ...
# 11499136   16097      N  <rt> <user> : <user> : i bet the jews did nazi...
# 14434181   19302      H                <user> <hashtag> white lives matter
# 17595333    4294      H  hamas to kids : shoot all the jews <url> <user...
# 23855851   14292      N  <rt> <user> : <user> <user> diversity = <hasht...
# 24250417    1658      N  <rt> <user> : stop  <allcaps> <hashtag> white ...
# 24255499    6740      N              <user> <hashtag> white genocide <url>
# 24255885    7126      N              <user> <hashtag> white genocide <url>
# 24262754   13995      N  <rt> <user> : <user> this is <hashtag> white g...
# 24263518   14759      N  <rt> <user> : cultural marxism = <hashtag> whi...
# 24347042   16843      N  <rt> <user> : best <hashtag> white genocide gr...
# 25837083     244      H        <user> : <hashtag> white lives matter <url>
# 26630350   19831      H  <rt> <user> : diversity / multiculturalism are...
# 26971448   14809      N  <rt> <user> : taggers ! <hashtag> white powerw...
# 29292522   14843      N  <rt> <user> : <hashtag> farm murders <hashtag>...
# 29295109   17430      N  <rt> <user> : <hashtag> fight <hashtag> white ...
# 29464184    3265      H  <user> flooding all  <allcaps> & only  <allcap...
# 30891510    5391      H   <rt> <user> : <hashtag> white lives matter <url>
# 30905942   19823      H   <rt> <user> : <hashtag> white lives matter <url>
# 30906235   20116      H   <rt> <user> : <hashtag> white lives matter <url>
# 30906236   20117      H   <rt> <user> : <hashtag> white lives matter <url>
# 30906237   20118      H   <rt> <user> : <hashtag> white lives matter <url>
# 30906238   20119      H   <rt> <user> : <hashtag> white lives matter <url>
# 35591909    2630      H  i said a glass of juice , not gas the jews -hi...
# 35608543   19264      H  i said a glass of juice , not gas the jews -hi...
# 36223787    3348      H  <user> <hashtag> diversity is a codeword for <...
# 39115452    3893      H  <hashtag> caucus for trump asia for the asians...
# 42578748    5989      H               <user> : <hashtag> white power <url>
# 42592131   19372      H               <user> : <hashtag> white power <url>
# 44098320   18921      N  white nationalism : the controversial idea tha...
# 45062258    5579      H  <rt> <user> : <user> <user> <user> diversity =...
# 53528188    1749      N  <rt> <user> : i said a glass of juice , not ga...
# 64720350   16271      N          <rt> <user> : <hashtag> white power <url>
# 66456487    1448      N  <rt> <user> : <user> flooding all  <allcaps> &...
# 68146699    1780      N  <rt> <user> : diversity is code for <hashtag> ...
# 70819857    7778      N                             <user> <user> the jews
# 70820351    8272      N                           <user> <user> the jews ?
# 71775516    6517      N                               <user> with the jews
# 77924737    7018      N                      <user> youre a fucking faggot
# 79149760   10441      N  <hashtag> rhode_island the shias are the donke...
# 79243041    1922      N  <rt> <user> : <hashtag> brexit <hashtag> u kin...
# 79243056    1937      N  <rt> <user> : asia for the asians , africa for...
# 81022830   10391      N  <hashtag> new_ york the shias are the donkeys ...
# 81103330    9451      N             <user> <hashtag> white lives mattertoo
# 81105867   11988      N             how about <hashtag> white lives matter
# 81112940   19061      N             wow <hashtag> white lives matter <url>
# 87406344     865      N    hamas to kids : shoot all the jews <user> <url>
# 89820052   12093      N        i ate the jews because it shouted at dave .
# 97729873    1874      N  <rt> <user> : i wouldve killed all the jews in...
# 99719834   16915      N  <rt> <user> : im  <allcaps> fucking done  <all...
# 99861980   16541      N  <rt> <user> : i could have killed all the jews...
# 101775213  15934      N                   <rt> <user> : where are the jews
# 102907334   7895      N                  <user> haha <hashtag> white power
# 104508040    161      N  <user> <user> <hashtag> white genocide is  <al...
# 104870876  16877      N  <rt> <user> : when nazis did this , global out...
# 105053098  15859      N  <rt> <user> : this was south africa <url> <has...
# 109741917   1518      N  <rt> <user> : love your race . <hashtag> white...
# 109749559   9160      N              <user> <hashtag> white lives matter !
# 109756670  16271      N          <rt> <user> : <hashtag> white power <url>
# 110162105  14506      N  <rt> <user> : mt  <allcaps> <user> prof k moha...
# 113570293   2214      N  <rt> <user> genocidehc : <user> <user> <user> ...
# 121917771   2092      N                <rt> <user> : <hashtag> white power
# 121922419   6740      N              <user> <hashtag> white genocide <url>
# 121922805   7126      N              <user> <hashtag> white genocide <url>
# 121923801   8122      N                   <user> <hashtag> white power . .
# 121930037  14358      N                <rt> <user> : <hashtag> white power
# 121931173  15494      N  <rt> <user> : <hashtag> white powerwednsday <url>
# 121931400  15721      N                <rt> <user> : <hashtag> white power
# 121932252  16573      N                <rt> <user> : <hashtag> white power
# 126089302  20183      H  <rt> <user> : where is the one who has been bo...
# 132197916    437      H                      <user> yes you fucking nigger
# 132583389  19430      H       <user> indeed . <hashtag> white lives matter
# 132669285   3526      H                               <user> kill the jews
# 137206609    570      H                 <user> <hashtag> white power <url>
# 137207231   1192      H  <rt> <user> : cucks <hashtag> white genocide <...
# 138426831  19552      H                    <hashtag> white lives mattertoo
# 139933471  19552      H                    <hashtag> white lives mattertoo
# 142869947   3828      H            <user> you are a massive fucking faggot
# 143394671  19552      H                    <hashtag> white lives mattertoo
# 145065569    570      H                 <user> <hashtag> white power <url>
# 145066191   1192      H  <rt> <user> : cucks <hashtag> white genocide <...
# 153004591  19552      H                    <hashtag> white lives mattertoo
# 155387723    204      H                    <user> untag you fucking nigger
# 156384351  19552      H                    <hashtag> white lives mattertoo
# 158343198   3479      H                     <user> <user> blame the jews !
# 160726894   5055      H                <rt> <user> : <hashtag> white power
# 165349548   5989      H               <user> : <hashtag> white power <url>
# 165362931  19372      H               <user> : <hashtag> white power <url>
# 165710283    244      H        <user> : <hashtag> white lives matter <url>
# 168401038   3479      H                     <user> <user> blame the jews !
# 169760871  19552      H                    <hashtag> white lives mattertoo
# 174097592  19593      H          blog : <hashtag> white lives matter <url>
# 174626911  19552      H                    <hashtag> white lives mattertoo
# 175279483    244      H        <user> : <hashtag> white lives matter <url>
# 176459183  19424      H                        <user> <user> <user> whut ?
# 176459187  19428      H                        <user> <user> <user> <user>
# 179310763    244      H        <user> : <hashtag> white lives matter <url>
# 179555083    244      H        <user> : <hashtag> white lives matter <url>
# 186252247  19328      H                              <user> so im the jews
# 186482630   5391      H   <rt> <user> : <hashtag> white lives matter <url>
# 186497062  19823      H   <rt> <user> : <hashtag> white lives matter <url>
# 186497355  20116      H   <rt> <user> : <hashtag> white lives matter <url>
# 186497356  20117      H   <rt> <user> : <hashtag> white lives matter <url>
# 186497357  20118      H   <rt> <user> : <hashtag> white lives matter <url>
# 186497358  20119      H   <rt> <user> : <hashtag> white lives matter <url>
# 189896687  19328      H                              <user> so im the jews
# 190243031  19552      H                    <hashtag> white lives mattertoo
# 192405983   3984      H                       <hashtag> white lives matter
# 192421429  19430      H       <user> indeed . <hashtag> white lives matter
# 192421544  19545      H                       <hashtag> white lives matter
# 192421545  19546      H                       <hashtag> white lives matter
# 195536631  19552      H                    <hashtag> white lives mattertoo
# 197409751  19552      H                    <hashtag> white lives mattertoo
# 197959471  19552      H                    <hashtag> white lives mattertoo
# 211544379   3980      H  <hashtag> virginia the shias are the donkeys o...
# 212559028    629      H  <hashtag> australia the shias are the donkeys ...
# 242385078  19639      H        heres where the jews hang out on xmas <url>
# 244059303   3984      H                       <hashtag> white lives matter
# 244074864  19545      H                       <hashtag> white lives matter
# 244074865  19546      H                       <hashtag> white lives matter
# 246197531   4412      H         i raped the jews because it touched dave .
# 263885192  19593      H          blog : <hashtag> white lives matter <url>
# 269606540  19781      H  <rt> <user> : never will the jews nor the chri...
# 269606762  20003      H  <rt> <user> : never will the jews nor the chri...
# 284919031   1192      H  <rt> <user> : cucks <hashtag> white genocide <...
# 290965931   1172      H  <rt> <user> : <user> <user> diversity = <hasht...
# 292314508   5989      H               <user> : <hashtag> white power <url>
# 292327891  19372      H               <user> : <hashtag> white power <url>
# 295327210   5411      H  <rt> <user> : professor khaleel mohammed says ...
# 299332123  19764      H         <rt> <user> : <hashtag> white lives matter
# 299332151  19792      H         <rt> <user> : <hashtag> white lives matter
# 299332301  19942      H         <rt> <user> : <hashtag> white lives matter
# 299332404  20045      H         <rt> <user> : <hashtag> white lives matter
# 300474071   1192      H  <rt> <user> : cucks <hashtag> white genocide <...
# 301492204   1325      H       <rt> <user> : <hashtag> white powerwednesday
# 302184558   1439      H  <rt> <user> : yes . <hashtag> war on whites <h...
# 303424409  19690      H  isis releases video in hebrew with a message t...
# 315443468   5989      H               <user> : <hashtag> white power <url>
# 315456851  19372      H               <user> : <hashtag> white power <url>
# 320065188   5989      H               <user> : <hashtag> white power <url>
# 320078571  19372      H               <user> : <hashtag> white power <url>
# 322874039   5160      H  <rt> <user> : white genocide in south africa :...
# 324400878   4999      H                 <rt> <user> : wake n bake the jews
# 327715124    565      H  <user> : i bet the jews did nazi us coming ! -...
# 331260378   3179      H                     <user> : <hashtag> white power
# 331262590   5391      H   <rt> <user> : <hashtag> white lives matter <url>
# 331276615  19416      H                     <user> : <hashtag> white power
# 331277022  19823      H   <rt> <user> : <hashtag> white lives matter <url>
# 331277315  20116      H   <rt> <user> : <hashtag> white lives matter <url>
# 331277316  20117      H   <rt> <user> : <hashtag> white lives matter <url>
# 331277317  20118      H   <rt> <user> : <hashtag> white lives matter <url>
# 331277318  20119      H   <rt> <user> : <hashtag> white lives matter <url>
# 333984966  19887      H         <rt> <user> : <user> <hashtag> white power
# 336759304   4905      H  <rt> <user> : i could have killed all the jews...
# 337411908   5989      H               <user> : <hashtag> white power <url>
# 337425291  19372      H               <user> : <hashtag> white power <url>
# 338180095    496      H  <user> : i set fire to the jews was also a goo...
# 342333335    296      H                        <user> : gas the jews <url>
# 342904315   1196      H  <rt> <user> : say no to <hashtag> white genoci...
# 344373937   4898      H  <rt> <user> : you  <allcaps> fucking nigger  <...
# 348501493  19734      H  mt <number> and asked , where is the one who h...
# 354855878   1439      H  <rt> <user> : yes . <hashtag> war on whites <h...
# 368576794  20075      H  <rt> <user> : i traveled to paris today to sta...
# 388065583   3984      H                       <hashtag> white lives matter
# 388081144  19545      H                       <hashtag> white lives matter
# 388081145  19546      H                       <hashtag> white lives matter
# 392196428   1749      N  <rt> <user> : i said a glass of juice , not ga...
# 392969068    709      N                    <hashtag> white lives mattertoo
# 393294188     69      N  <user> <user> <user> [<number>] o you who beli...
# 393506867   9148      N                                <user> for the jews
# 393507046   9327      N                                <user> for the jews
# 394395651   2092      N                <rt> <user> : <hashtag> white power
# 394400299   6740      N              <user> <hashtag> white genocide <url>
# 394400685   7126      N              <user> <hashtag> white genocide <url>
# 394401681   8122      N                   <user> <hashtag> white power . .
# 394407917  14358      N                <rt> <user> : <hashtag> white power
# 394409053  15494      N  <rt> <user> : <hashtag> white powerwednsday <url>
# 394409280  15721      N                <rt> <user> : <hashtag> white power
# 394410132  16573      N                <rt> <user> : <hashtag> white power
# 395305670  16271      N          <rt> <user> : <hashtag> white power <url>
# 395460946   8667      N                               <user> <user> <user>
# 395542386   8667      N                               <user> <user> <user>
# 395580951   6512      N        <user> : <url> <hashtag> white lives matter
# 395583890   9451      N             <user> <hashtag> white lives mattertoo
# 395642948   7429      N                  <user> <user> shias or the jews ?
# 397925290   9451      N             <user> <hashtag> white lives mattertoo
# 397927827  11988      N             how about <hashtag> white lives matter
# 397934900  19061      N             wow <hashtag> white lives matter <url>
# 397945650   9451      N             <user> <hashtag> white lives mattertoo
# 397948187  11988      N             how about <hashtag> white lives matter
# 397955260  19061      N             wow <hashtag> white lives matter <url>
# 398058846    487      N                <user> <hashtag> white lives matter
# 398065158   6799      N                <user> <hashtag> white lives matter
# 398065232   6873      N                <user> <hashtag> white lives matter
# 398065402   7043      N                <user> <hashtag> white lives matter
# 398065874   7515      N                <user> <hashtag> white lives matter
# 398066040   7681      N                <user> <hashtag> white lives matter
# 398066697   8338      N                <user> <hashtag> white lives matter
# 398066936   8577      N                <user> <hashtag> white lives matter
# 398067703   9344      N                <user> <hashtag> white lives matter
# 398067963   9604      N                <user> <hashtag> white lives matter
# 398068055   9696      N                <user> <hashtag> white lives matter
# 398068082   9723      N                <user> <hashtag> white lives matter
# 398901670   8551      N          <user> <hashtag> white lives matter <url>
# 399841584  11905      N  heres where all the jews are hanging out on xm...
# 400882942  14903      N  <rt> <user> : isis  <allcaps> releases video i...
# 401780996  17117      N  <rt> <user> : where is the one who has been bo...
# 402389381  14702      N  <rt> <user> : amen pat <hashtag> white lives m...
# 402734041  13242      N  never will the jews nor the christians be plea...
# 402959461  14702      N  <rt> <user> : amen pat <hashtag> white lives m...
# 403577437   1518      N  <rt> <user> : love your race . <hashtag> white...
# 403585079   9160      N              <user> <hashtag> white lives matter !
# 403592190  16271      N          <rt> <user> : <hashtag> white power <url>
# 403740107   1308      N  <rt> <user> : diversity is a racist euphemism ...
# 404895363  16404      N  <rt> <user> : happy birthday <user> <hashtag> ...
# 406013461  14702      N  <rt> <user> : amen pat <hashtag> white lives m...
# 407253961  13242      N  never will the jews nor the christians be plea...
# 408110541  14702      N  <rt> <user> : amen pat <hashtag> white lives m...
# 408724742  18103      N  the jews are in ethiopia rt  <allcaps> <user> ...
# 409542917   1518      N  <rt> <user> : love your race . <hashtag> white...
# 409550559   9160      N              <user> <hashtag> white lives matter !
# 409557670  16271      N          <rt> <user> : <hashtag> white power <url>
# 409563277   1518      N  <rt> <user> : love your race . <hashtag> white...
# 409570919   9160      N              <user> <hashtag> white lives matter !
# 409578030  16271      N          <rt> <user> : <hashtag> white power <url>
# 409583637   1518      N  <rt> <user> : love your race . <hashtag> white...
# 409591279   9160      N              <user> <hashtag> white lives matter !
# 409598390  16271      N          <rt> <user> : <hashtag> white power <url>
# 409603997   1518      N  <rt> <user> : love your race . <hashtag> white...
# 409611639   9160      N              <user> <hashtag> white lives matter !
# 409618750  16271      N          <rt> <user> : <hashtag> white power <url>
# 410911712   6193      N  . <repeat>where is he who has been born king o...
#
#            score
# 4140712       85
# 4948749       85
# 4955619       85
# 4956089       85
# 4956287       85
# 4956299       85
# 6023014       85
# 8883453       85
# 9914511       85
# 10094810      85
# 11499136      85
# 14434181      85
# 17595333      85
# 23855851      85
# 24250417      85
# 24255499      85
# 24255885      85
# 24262754      85
# 24263518      85
# 24347042      85
# 25837083      85
# 26630350      85
# 26971448      85
# 29292522      85
# 29295109      85
# 29464184      85
# 30891510      85
# 30905942      85
# 30906235      85
# 30906236      85
# 30906237      85
# 30906238      85
# 35591909      85
# 35608543      85
# 36223787      85
# 39115452      85
# 42578748      85
# 42592131      85
# 44098320      85
# 45062258      85
# 53528188      85
# 64720350      85
# 66456487      85
# 68146699      85
# 70819857      85
# 70820351      85
# 71775516      85
# 77924737      85
# 79149760      85
# 79243041      85
# 79243056      85
# 81022830      85
# 81103330      85
# 81105867      85
# 81112940      85
# 87406344      85
# 89820052      85
# 97729873      85
# 99719834      85
# 99861980      85
# 101775213     85
# 102907334     85
# 104508040     85
# 104870876     85
# 105053098     85
# 109741917     85
# 109749559     85
# 109756670     85
# 110162105     85
# 113570293     85
# 121917771     85
# 121922419     85
# 121922805     85
# 121923801     85
# 121930037     85
# 121931173     85
# 121931400     85
# 121932252     85
# 126089302     85
# 132197916     85
# 132583389     85
# 132669285     85
# 137206609     85
# 137207231     85
# 138426831     85
# 139933471     85
# 142869947     85
# 143394671     85
# 145065569     85
# 145066191     85
# 153004591     85
# 155387723     85
# 156384351     85
# 158343198     85
# 160726894     85
# 165349548     85
# 165362931     85
# 165710283     85
# 168401038     85
# 169760871     85
# 174097592     85
# 174626911     85
# 175279483     85
# 176459183     85
# 176459187     85
# 179310763     85
# 179555083     85
# 186252247     85
# 186482630     85
# 186497062     85
# 186497355     85
# 186497356     85
# 186497357     85
# 186497358     85
# 189896687     85
# 190243031     85
# 192405983     85
# 192421429     85
# 192421544     85
# 192421545     85
# 195536631     85
# 197409751     85
# 197959471     85
# 211544379     85
# 212559028     85
# 242385078     85
# 244059303     85
# 244074864     85
# 244074865     85
# 246197531     85
# 263885192     85
# 269606540     85
# 269606762     85
# 284919031     85
# 290965931     85
# 292314508     85
# 292327891     85
# 295327210     85
# 299332123     85
# 299332151     85
# 299332301     85
# 299332404     85
# 300474071     85
# 301492204     85
# 302184558     85
# 303424409     85
# 315443468     85
# 315456851     85
# 320065188     85
# 320078571     85
# 322874039     85
# 324400878     85
# 327715124     85
# 331260378     85
# 331262590     85
# 331276615     85
# 331277022     85
# 331277315     85
# 331277316     85
# 331277317     85
# 331277318     85
# 333984966     85
# 336759304     85
# 337411908     85
# 337425291     85
# 338180095     85
# 342333335     85
# 342904315     85
# 344373937     85
# 348501493     85
# 354855878     85
# 368576794     85
# 388065583     85
# 388081144     85
# 388081145     85
# 392196428     85
# 392969068     85
# 393294188     85
# 393506867     85
# 393507046     85
# 394395651     85
# 394400299     85
# 394400685     85
# 394401681     85
# 394407917     85
# 394409053     85
# 394409280     85
# 394410132     85
# 395305670     85
# 395460946     85
# 395542386     85
# 395580951     85
# 395583890     85
# 395642948     85
# 397925290     85
# 397927827     85
# 397934900     85
# 397945650     85
# 397948187     85
# 397955260     85
# 398058846     85
# 398065158     85
# 398065232     85
# 398065402     85
# 398065874     85
# 398066040     85
# 398066697     85
# 398066936     85
# 398067703     85
# 398067963     85
# 398068055     85
# 398068082     85
# 398901670     85
# 399841584     85
# 400882942     85
# 401780996     85
# 402389381     85
# 402734041     85
# 402959461     85
# 403577437     85
# 403585079     85
# 403592190     85
# 403740107     85
# 404895363     85
# 406013461     85
# 407253961     85
# 408110541     85
# 408724742     85
# 409542917     85
# 409550559     85
# 409557670     85
# 409563277     85
# 409570919     85
# 409578030     85
# 409583637     85
# 409591279     85
# 409598390     85
# 409603997     85
# 409611639     85
# 409618750     85
# 410911712     85

# %%
fuzz_similarity['score'] = ratios

# %%
#Limit to only pairs of tweets with scores over 85
over85 = fuzz_similarity[fuzz_similarity['score']>85]
#Get the IDs of all tweets taht appear in these rows (so that they can be dropped in data build notebook)
duplicate_IDs = np.unique(np.append(over85['ID_x'], over85['ID_y']))

# %% [markdown]
# ## Export for use in main notebook

# %%
np.save('duplicate_fuzzy_ids.npy', duplicate_IDs)
